# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('customer-recipes.csv')
data.head(10)
# Out:
#   Customer Code First Name Last Name                   Email  \
# 0        JL9123     Elliot      King    elliotking@gmail.com
# 1        JL8152       Noel      Hall      noelhall@gmail.com
# 2        JL8315     Robert    Wright  robertwright@gmail.com
# 3        JL8753    Addison       Lee    addisonlee@gmail.com
# 4        JL7123      Bobby      Gray     bobbygray@gmail.com
# 5        JL0961     Gordon    Hamsay  gordonhamsay@gmail.com
# 6        JL7812        Guy   Mustang    guymustang@gmail.com
# 7        JL8715       Abed    Glover   abed.glover@gmail.com
# 8        JL8018      Avery    Malone       amalone@gmail.com
# 9        JL3761     Taylor      Zhou   taylor_zhou@gmail.com
#
#                Job Title                       Recipe  Recipe Score  \
# 0         Data Scientist             Leftover Burrito             4
# 1          UX Researcher               Eggs in a Nest             7
# 2         Data Scientist            Loaded Tater Tots             9
# ...
