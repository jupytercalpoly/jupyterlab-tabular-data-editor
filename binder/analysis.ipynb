# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('customer-recipes.csv')
data.head(10)
# Out:
#   Customer Code First Name  Last Name                 Job Title  \
# 0        JL7321    Timothy     George       Lead UX/UI Designer
# 1        JL9123     Elliot       King            Data Scientist
# 2        JL8152       Noel       Hall             UX Researcher
# 3        JL8315     Robert     Wright            Data Scientist
# 4        JL0917    Zachary     Sailer    Lead Software Engineer
# 5        JL8753    Addison        Lee     Senior Data Scientist
# 6        JL1032        Jay        Ahn  Software Engineer Intern
# 7        JL5362    Cameron        Toy  Software Engineer Intern
# 8        JL7163      Ai-Vy       Dang       UX/UI Design Intern
# 9        JL3124      Logan  McNichols  Software Engineer Intern
#
#                   Recipe  Recipe Score                      Email    Location  \
# 0    Snozzberry Surprise            10        timsfilez@gmail.com  California
# 1       Leftover Burrito             4       elliotking@gmail.com    New York
# ...
